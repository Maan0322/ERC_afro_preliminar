# %% [markdown]
# ## **Librerias:**

# %%
import pandas as pd
from scipy.stats import shapiro
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp

# %% [markdown]
# ### **Funciones:**

# %%
def prueba_normalidad_shap (df, variable):
    stat, p = shapiro(df[variable].dropna())
    print('Estadístico=%.3f, p=%.3f' % (stat, p))

    if p > 0.05:
        print('No se rechaza H0 → parece normal')
    else:
        print('Se rechaza H0 → no es normal')

# %%
def analizar_misma_variable(df1, df2, columna, color1="#4682B4", color2="#FF6347"):
    # Crear una figura con dos filas y dos columnas
    f, ((ax_box1, ax_hist1), (ax_box2, ax_hist2)) = plt.subplots(2, 2, sharex='col', figsize=(12, 10))
    
    # Primer par de gráficos (boxplot y histograma para columna en df1)
    sns.boxplot(x=df1[columna], ax=ax_box1, color=color1, fliersize=5)
    ax_box1.set(xlabel='') 
    ax_box1.set_title(f'Distribución de la Variable: {columna} en df1', fontsize=14)
    
    sns.histplot(df1[columna], ax=ax_hist1, kde=True, color=color1, bins=30)
    ax_hist1.set_xlabel(f'Valores de {columna}', fontsize=12)
    ax_hist1.set_ylabel('Frecuencia', fontsize=12)
    
    # Segundo par de gráficos (boxplot y histograma para columna en df2)
    sns.boxplot(x=df2[columna], ax=ax_box2, color=color2, fliersize=5)
    ax_box2.set(xlabel='') 
    ax_box2.set_title(f'Distribución de la Variable: {columna} en df2', fontsize=14)
    
    sns.histplot(df2[columna], ax=ax_hist2, kde=True, color=color2, bins=30)
    ax_hist2.set_xlabel(f'Valores de {columna}', fontsize=12)
    ax_hist2.set_ylabel('Frecuencia', fontsize=12)
    
    plt.tight_layout()  # Ajustar espaciado
    plt.show()

# %%
def analizar_distribucion(df, columna, color="#4682B4"):
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                        gridspec_kw={"height_ratios": (.15, .85)},
                                        figsize=(8, 6))
    
    sns.boxplot(x=df[columna], ax=ax_box, color=color, fliersize=5)
    ax_box.set(xlabel='') 
    ax_box.set_title(f'Distribución de la Variable: {columna}', fontsize=14)
    
    sns.histplot(df[columna], ax=ax_hist, kde=True, color=color, bins=30)
    ax_hist.set_xlabel(f'Valores de {columna}', fontsize=12)
    ax_hist.set_ylabel('Frecuencia', fontsize=12)
    
    plt.tight_layout()
    plt.show()

# %%
def distribucion_cruzada (df_original, df_imputed, variable):
    sns.kdeplot(df_original[variable].dropna(), label='Original')
    sns.kdeplot(df_imputed[variable], label='Imputado')
    plt.legend()
    plt.show()

# %%
def Resumen_Faltantes(df):
    faltantes = df.isnull().sum()
    porcentaje = (faltantes / len(df)) * 100

    tabla_faltantes = pd.DataFrame({
        'Valores faltantes': faltantes,
        'Porcentaje (%)': porcentaje
    })

    # Mostrar solo columnas con NA
    tabla_faltantes = tabla_faltantes[tabla_faltantes['Valores faltantes'] > 0]
    tabla_faltantes.sort_values('Porcentaje (%)', ascending=False)
    return tabla_faltantes

# %%
def resumen_var_cat(df):
    conteo = df.value_counts(dropna=False)
    porcentaje = df.value_counts(normalize=True, dropna=False) * 100
    
    resumen = pd.DataFrame({
        'categorias': conteo.index,
        'conteo': conteo.values,
        'porcentaje': porcentaje.values.round(2)
    })
    
    resumen = resumen.head(10)  # opcional
    
    # 🎨 estilo bonito
    styled = resumen.style \
        .format({'porcentaje': '{:.2f}%'})
    
    display(styled)

# %%
def prueba_kolmogrov(df_original,df_imputed,variable):
    stat, p = ks_2samp(df_original[variable].dropna(), df_imputed[variable].dropna())
    print(f"KS statistic: {stat:.3f}, p-value: {p:.3f}")

    if(p > 0.05):
        print("No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran")
    else:
        print("La distribución cambió significativamente")

# %%
def imputacion_muestreo_aleatorio(df, df_imputed, variable):
    # 1. Tomar valores reales (sin NA)
    valores = df[variable].dropna()

    # 2. Contar cuántos faltan
    n_faltantes = df[variable].isna().sum()

    # 3. Rellenar con valores aleatorios de la distribución real
    # Asegurándonos de que imputamos sobre el DataFrame correcto (df_imputed)
    df_imputed.loc[df_imputed[variable].isna(), variable] = np.random.choice(
        valores, 
        size=n_faltantes
    )
    
    return df_imputed

# %%
def imputacion_por_mediana(df, columna):
    # 1. Calcular la mediana de la columna
    mediana = df[columna].median()

    # 2. Imputar los valores faltantes con la mediana
    df[columna].fillna(mediana, inplace=True)

    return df

# %% [markdown]
# ## **Cargar datos:**

# %%
df = pd.read_excel("df_afro_clean.xlsx")

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs  Cantidad_Fumador  \
# 0       No        No aplica             No              No               NaN
# 1       No        No aplica             No              No               NaN
# 2       No        No aplica             No              No               NaN
# 3       No        No aplica             No              No               NaN
# 4       No        No aplica             No              No               NaN
#
#   Consumo_Alcohol    Frecuencia_Alcohol Embriaguez Consumo_Drogas  \
# 0              No                 Nunca         No             No
# 1              Si     1-2 veces por mes         No             No
# 2              Si  1-2 veces por semana         No             No
# 3              Si     1-2 veces por mes         No             No
# 4              No                 Nunca         No             No
#
#   Trabajo_Cultivo Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes  \
# 0              No               No             No                No
# 1              No               No             No                No
# 2              No               No             No                No
# 3              No               No             No                No
# 4              No               No             No                No
#
#   Proteccion_Pesticidas Metodo_Aplicacion_Pesticidas Sintomas_Trabajo  \
# 0             No aplica                    No aplica   No siente nada
# 1             No aplica                    No aplica   No siente nada
# 2             No aplica                    No aplica  Dolor de cabeza
# 3             No aplica                    No aplica   No siente nada
# 4             No aplica                    No aplica   No siente nada
#
#   Consumo_Agua_Trabajo Ultima_Consulta_Medica Dificultad_Atencion_Medica  \
# 0       Mas de 1 litro        Mayor a 3 meses                Muy Dificil
# 1        Mas de 200 cc        Mayor a 3 meses                    Difícil
# 2       Mas de 1 litro         Mayor a 2 años                      Facil
# 3         No toma nada         Mayor a 2 años                Muy Dificil
# 4       Mas de 1 litro         Mayor a 2 años                    Difícil
#
#   Ultimo_Profesional_Salud Medico_Cabecera Grupo_Sanguineo  \
# 0               Internista              Si              B+
# 1           Medico General              No              O+
# 2           Medico General              No              O+
# 3           Medico General              No              A+
# 4           Medico General              Si              O+
#
#   Transfusion_Sanguinea Antecedentes_Familiares Familiar_Insuficiencia_Renal  \
# 0                    No   Hipertensión Arterial                           No
# 1                    No   Hipertensión Arterial                           No
# 2                    No   Hipertensión Arterial                           Sí
# 3                    No       Diabetes Mellitus                           No
# 4                    No   Hipertensión Arterial                           No
#
#   Familiar_Dialisis Sintomas_Recientes Uso_AINES Uso_Medicina_Natural  \
# 0                No            Ninguno        No                   No
# 1                No            Ninguno        No                   No
# 2                No    Dolor de cabeza        Si                   Si
# 3                No    Dolor de cabeza        Si                   Si
# 4                No            Ninguno        No                   No
#
#             Fuente_Agua  Peso  Talla        IMC Tirilla_Reactiva  Creatinina  \
# 0  Suministro municipal    63   1.66  22.862534         Negativo         0.9
# 1  Suministro municipal    75   1.63  28.228386         Negativo         0.7
# 2  Suministro municipal    97   1.68  34.367914         Negativo         NaN
# 3  Suministro municipal    65   1.62  24.767566         Negativo         NaN
# 4  Suministro municipal    70   1.57  28.398718         Negativo         NaN
#
#    TFG_CDK_EPI  TFG_Edad  Presion_Sistolica  Presion_Diastolica  \
# 0        82.26      73.0              175.0                89.0
# 1       116.28     102.0               97.0                70.0
# 2          NaN       NaN               92.0                68.0
# 3          NaN       NaN              105.0                63.0
# 4          NaN       NaN              126.0                71.0
#
#   Creatinina_Alta  Presion_Sistolica\t> 130  Presion_Diastolica > 90  \
# 0              No                         1                        0
# 1              No                         0                        0
# 2              No                         0                        0
# 3              No                         0                        0
# 4              No                         0                        0
#
#   Categoria_Talla Categoria_Peso Categoria_IMC
# 0       1.61-1.70          61-80        Normal
# 1       1.61-1.70          61-80          Alto
# 2       1.61-1.70            >80    Obesidad 1
# 3       1.61-1.70          61-80        Normal
# 4       1.50-1.60          61-80          Alto

# %% [markdown]
# ## **Observando los datos:**

# %% [markdown]
# ### **Tipos de Datos:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1357 entries, 0 to 1356
# Data columns (total 62 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GRUPO                         1357 non-null   object
#  1   Departamento_Tamizaje         1357 non-null   object
#  2   Municipio_Tamizaje            1357 non-null   object
#  3   Edad                          1357 non-null   int64
#  4   Genero                        1357 non-null   object
#  5   Escolaridad                   1357 non-null   object
#  6   Regimen_Salud                 1357 non-null   object
#  7   Ocupacion                     1357 non-null   object
#  8   Medicacion_Diabetes           1357 non-null   object
#  9   Diabetes_Embarazo             1357 non-null   object
#  10  Hipertension                  1357 non-null   object
#  11  Medicacion_Hipertension       1357 non-null   object
#  12  Colesterol_Alto               1357 non-null   object
#  13  Medicacion_Colesterol         1357 non-null   object
#  14  Insuficiencia_Renal           1357 non-null   object
#  15  Dialisis                      1357 non-null   object
#  16  Proteina_Sangre_Orina         1357 non-null   object
#  17  Alergias                      1357 non-null   object
#  18  Nombre_Alergenos              1357 non-null   object
#  19  Consumo_Tabaco                1357 non-null   object
#  20  Fumador_100Cigs               1357 non-null   object
#  21  Cantidad_Fumador              0 non-null      float64
#  22  Consumo_Alcohol               1357 non-null   object
#  23  Frecuencia_Alcohol            1357 non-null   object
#  24  Embriaguez                    1357 non-null   object
#  25  Consumo_Drogas                1357 non-null   object
#  26  Trabajo_Cultivo               1357 non-null   object
#  27  Uso_Insecticidas              1357 non-null   object
#  28  Uso_Fungicidas                1357 non-null   object
#  29  Uso_Fertilizantes             1357 non-null   object
#  30  Proteccion_Pesticidas         1357 non-null   object
#  31  Metodo_Aplicacion_Pesticidas  1357 non-null   object
#  32  Sintomas_Trabajo              1357 non-null   object
#  33  Consumo_Agua_Trabajo          1357 non-null   object
#  34  Ultima_Consulta_Medica        1357 non-null   object
#  35  Dificultad_Atencion_Medica    1357 non-null   object
#  36  Ultimo_Profesional_Salud      1357 non-null   object
#  37  Medico_Cabecera               1357 non-null   object
#  38  Grupo_Sanguineo               1357 non-null   object
#  39  Transfusion_Sanguinea         1357 non-null   object
#  40  Antecedentes_Familiares       1357 non-null   object
#  41  Familiar_Insuficiencia_Renal  1357 non-null   object
#  42  Familiar_Dialisis             1357 non-null   object
#  43  Sintomas_Recientes            1357 non-null   object
#  44  Uso_AINES                     1357 non-null   object
#  45  Uso_Medicina_Natural          1357 non-null   object
#  46  Fuente_Agua                   1357 non-null   object
#  47  Peso                          1357 non-null   int64
#  48  Talla                         1357 non-null   float64
#  49  IMC                           1357 non-null   float64
#  50  Tirilla_Reactiva              1357 non-null   object
#  51  Creatinina                    470 non-null    float64
#  52  TFG_CDK_EPI                   470 non-null    float64
#  53  TFG_Edad                      470 non-null    float64
#  54  Presion_Sistolica             1310 non-null   float64
#  55  Presion_Diastolica            1310 non-null   float64
#  56  Creatinina_Alta               1357 non-null   object
#  57  Presion_Sistolica	> 130       1357 non-null   int64
#  58  Presion_Diastolica > 90       1357 non-null   int64
#  59  Categoria_Talla               1357 non-null   object
#  60  Categoria_Peso                1357 non-null   object
#  61  Categoria_IMC                 1357 non-null   object
# dtypes: float64(8), int64(4), object(50)
# memory usage: 657.4+ KB

# %%
num_registros = len(df)
num_variables = len(df.columns)
num_numericas = df.select_dtypes(include='number').shape[1]
num_categoricas = df.select_dtypes(include='object').shape[1]

print(f"Tenemos un conjunto de datos compuesto por {num_registros} registros y {num_variables} variables, de las cuales {num_numericas} son numéricas y {num_categoricas} son categóricas.")
# Out:
# Tenemos un conjunto de datos compuesto por 1357 registros y 62 variables, de las cuales 12 son numéricas y 50 son categóricas.

# %% [markdown]
# ### **Nombres de las variables Numéricas:**

# %%
df.select_dtypes(include = "number").columns
# Out:
# Index(['Edad', 'Cantidad_Fumador', 'Peso', 'Talla', 'IMC', 'Creatinina',
#        'TFG_CDK_EPI', 'TFG_Edad', 'Presion_Sistolica', 'Presion_Diastolica',
#        'Presion_Sistolica\t> 130', 'Presion_Diastolica > 90'],
#       dtype='object')

# %% [markdown]
# ### **Nombres de las Variables Categóricas:**

# %%
df.select_dtypes(include = "object").columns
# Out:
# Index(['GRUPO', 'Departamento_Tamizaje', 'Municipio_Tamizaje', 'Genero',
#        'Escolaridad', 'Regimen_Salud', 'Ocupacion', 'Medicacion_Diabetes',
#        'Diabetes_Embarazo', 'Hipertension', 'Medicacion_Hipertension',
#        'Colesterol_Alto', 'Medicacion_Colesterol', 'Insuficiencia_Renal',
#        'Dialisis', 'Proteina_Sangre_Orina', 'Alergias', 'Nombre_Alergenos',
#        'Consumo_Tabaco', 'Fumador_100Cigs', 'Consumo_Alcohol',
#        'Frecuencia_Alcohol', 'Embriaguez', 'Consumo_Drogas', 'Trabajo_Cultivo',
#        'Uso_Insecticidas', 'Uso_Fungicidas', 'Uso_Fertilizantes',
#        'Proteccion_Pesticidas', 'Metodo_Aplicacion_Pesticidas',
#        'Sintomas_Trabajo', 'Consumo_Agua_Trabajo', 'Ultima_Consulta_Medica',
#        'Dificultad_Atencion_Medica', 'Ultimo_Profesional_Salud',
#        'Medico_Cabecera', 'Grupo_Sanguineo', 'Transfusion_Sanguinea',
#        'Antecedentes_Familiares', 'Familiar_Insuficiencia_Renal',
#        'Familiar_Dialisis', 'Sintomas_Recientes', 'Uso_AINES',
#        'Uso_Medicina_Natural', 'Fuente_Agua', 'Tirilla_Reactiva',
#        'Creatinina_Alta', 'Categoria_Talla', 'Categoria_Peso',
#        'Categoria_IMC'],
#       dtype='object')

# %% [markdown]
# ### **Notas:**

# %% [markdown]
# Se evidencia la ausencia de una variable que funcione como identificador único del paciente, lo cual dificulta diferenciar correctamente los registros y garantizar que el formulario no haya sido aplicado más de una vez a la misma persona.

# %% [markdown]
# ## **Duplicados:**

# %%
print("En este dataset podemos encontrar {} resgistros duplicados".format(df.duplicated().sum()))
# Out:
# En este dataset podemos encontrar 1 resgistros duplicados

# %%
df[df.duplicated(keep = False)]
# Out:
#                  GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad  \
# 407   AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    41
# 1023  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    41
#
#         Genero Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 407   Femenino     Técnica      No tiene  Desempleado                  No
# 1023  Femenino     Técnica      No tiene  Desempleado                  No
#
#      Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 407                 No           No                      No              No
# 1023                No           No                      No              No
#
#      Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 407                     No                  No       No                    No
# 1023                    No                  No       No                    No
#
#      Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs  \
# 407        No        No aplica             No              No
# 1023       No        No aplica             No              No
#
#       Cantidad_Fumador Consumo_Alcohol Frecuencia_Alcohol Embriaguez  \
# 407                NaN              Si  1-2 veces por mes         No
# 1023               NaN              Si  1-2 veces por mes         No
#
#      Consumo_Drogas Trabajo_Cultivo Uso_Insecticidas Uso_Fungicidas  \
# 407              No              No               No             No
# 1023             No              No               No             No
#
#      Uso_Fertilizantes Proteccion_Pesticidas Metodo_Aplicacion_Pesticidas  \
# 407                 No             No aplica                    No aplica
# 1023                No             No aplica                    No aplica
#
#      Sintomas_Trabajo Consumo_Agua_Trabajo Ultima_Consulta_Medica  \
# 407    No siente nada      Mas de 5 litros        Mayor a 6 meses
# 1023   No siente nada      Mas de 5 litros        Mayor a 6 meses
#
#      Dificultad_Atencion_Medica Ultimo_Profesional_Salud Medico_Cabecera  \
# 407                     Difícil           Medico General              No
# 1023                    Difícil           Medico General              No
#
#      Grupo_Sanguineo Transfusion_Sanguinea Antecedentes_Familiares  \
# 407               O+                    No     Enfermedad Cardiaca
# 1023              O+                    No     Enfermedad Cardiaca
#
#      Familiar_Insuficiencia_Renal Familiar_Dialisis Sintomas_Recientes  \
# 407                            No                No            Ninguno
# 1023                           No                No            Ninguno
#
#      Uso_AINES Uso_Medicina_Natural           Fuente_Agua  Peso  Talla  \
# 407         No                   No  Suministro municipal    85    1.8
# 1023        No                   No  Suministro municipal    85    1.8
#
#             IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 407   26.234568         Negativo         NaN          NaN       NaN
# 1023  26.234568         Negativo         NaN          NaN       NaN
#
#       Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 407               110.0                60.0              No
# 1023              110.0                60.0              No
#
#       Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 407                          0                        0           >1.70
# 1023                         0                        0           >1.70
#
#      Categoria_Peso Categoria_IMC
# 407             >80          Alto
# 1023            >80          Alto

# %% [markdown]
# Ante la presencia de un registro duplicado, se procederá a conservar el que aparece en primer lugar y a eliminar aquel que se encuentra en una posición posterior, bajo el supuesto de que el primer registro corresponde a la captura original y los siguientes podrían derivarse de errores de digitación, reprocesamiento o redundancias en la recolección de la información.

# %%
df= df.drop_duplicates(keep='first')
print("Dentro del dataset aun quedan {} registros duplicados".format(df.duplicated().sum()))
# Out:
# Dentro del dataset aun quedan 0 registros duplicados

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [GRUPO, Departamento_Tamizaje, Municipio_Tamizaje, Edad, Genero, Escolaridad, Regimen_Salud, Ocupacion, Medicacion_Diabetes, Diabetes_Embarazo, Hipertension, Medicacion_Hipertension, Colesterol_Alto, Medicacion_Colesterol, Insuficiencia_Renal, Dialisis, Proteina_Sangre_Orina, Alergias, Nombre_Alergenos, Consumo_Tabaco, Fumador_100Cigs, Cantidad_Fumador, Consumo_Alcohol, Frecuencia_Alcohol, Embriaguez, Consumo_Drogas, Trabajo_Cultivo, Uso_Insecticidas, Uso_Fungicidas, Uso_Fertilizantes, Proteccion_Pesticidas, Metodo_Aplicacion_Pesticidas, Sintomas_Trabajo, Consumo_Agua_Trabajo, Ultima_Consulta_Medica, Dificultad_Atencion_Medica, Ultimo_Profesional_Salud, Medico_Cabecera, Grupo_Sanguineo, Transfusion_Sanguinea, Antecedentes_Familiares, Familiar_Insuficiencia_Renal, Familiar_Dialisis, Sintomas_Recientes, Uso_AINES, Uso_Medicina_Natural, Fuente_Agua, Peso, Talla, IMC, Tirilla_Reactiva, Creatinina, TFG_CDK_EPI, TFG_Edad, Presion_Sistolica, Presion_Diastolica, Creatinina_Alta, Presion_Sistolica	> 130, Presion_Diastolica > 90, Categoria_Talla, Categoria_Peso, Categoria_IMC]
# Index: []

# %% [markdown]
# ## **Valores Faltantes:**

# %% [markdown]
# A continuación, se procederá a analizar el porcentaje de valores faltantes en cada una de las variables del conjunto de datos.

# %%
plt.figure(figsize = (20,6))
sns.heatmap(df.isnull(),cbar=False,cmap= "Blues")
plt.title("Mapa de calor de Valores Faltantes")
plt.xlabel("Variables")
plt.ylabel("Regsitros")
plt.show()
# Out:
# c:\Users\Mari\miniconda3\envs\deepl_venv\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Mari\miniconda3\envs\deepl_venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
Resumen_Faltantes(df)
# Out:
#                     Valores faltantes  Porcentaje (%)
# Cantidad_Fumador                 1356      100.000000
# Creatinina                        886       65.339233
# TFG_CDK_EPI                       886       65.339233
# TFG_Edad                          886       65.339233
# Presion_Sistolica                  47        3.466077
# Presion_Diastolica                 47        3.466077

# %% [markdown]
# La variable ``Cantidad_Fumador``, al encontrarse completamente vacía, será eliminada de la base de datos.

# %%
df = df.drop(columns=['Cantidad_Fumador'])
df.head()
# Out:
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo         0.9        82.26      73.0
# 1    75   1.63  28.228386         Negativo         0.7       116.28     102.0
# 2    97   1.68  34.367914         Negativo         NaN          NaN       NaN
# 3    65   1.62  24.767566         Negativo         NaN          NaN       NaN
# 4    70   1.57  28.398718         Negativo         NaN          NaN       NaN
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %% [markdown]
#  Por otro lado, las variables ``Presion_Sistolica`` y ``Presion_Diastolica`` presentan un 3.46% de valores faltantes (aproximadamente 47 registros), por lo que podrían imputarse mediante medidas de tendencia central como la media o la mediana; no obstante, esta decisión debe evaluarse previamente.
#
# En cuanto a las variables ``Creatinina``, ``TFG_CDK_EPI`` y ``TFG_Edad``, la situación es más compleja, ya que presentan un 65.34% de valores faltantes (alrededor de 886 registros). Dada esta alta proporción, sería necesario considerar métodos de imputación más avanzados, como modelos predictivos. Sin embargo, es fundamental evaluar cuidadosamente que dichos métodos no alteren de manera significativa la distribución original de los datos ni introduzcan sesgos en el análisis.

# %% [markdown]
# ## **Análisis Variables Numéricas para Imputar:**

# %% [markdown]
# ### ``Presion_Sistolica``, ``Presion_Diastolica``, `Creatinina`

# %% [markdown]
# #### **Distribución con Valores Faltantes:**

# %%
df[['TFG_Edad','TFG_CDK_EPI','Creatinina']].describe()
# Out:
#          TFG_Edad  TFG_CDK_EPI  Creatinina
# count  470.000000   470.000000  470.000000
# mean    82.536170    81.542596    1.156787
# std     17.417419    31.470822    0.388140
# min     33.000000    22.140000    0.600000
# 25%     71.250000    54.545000    0.806750
# 50%     82.000000    78.830000    1.000000
# 75%     94.000000   105.972500    1.479500
# max    116.000000   168.190000    2.500000

# %%
analizar_distribucion(df,"TFG_Edad")

# %%
prueba_normalidad_shap(df,"TFG_Edad")
# Out:
# Estadístico=0.982, p=0.000
# Se rechaza H0 → no es normal

# %%
analizar_distribucion(df,"TFG_CDK_EPI")

# %%
prueba_normalidad_shap(df,"TFG_CDK_EPI")
# Out:
# Estadístico=0.974, p=0.000
# Se rechaza H0 → no es normal

# %%
analizar_distribucion(df,"Creatinina")

# %%
prueba_normalidad_shap(df,"Creatinina")
# Out:
# Estadístico=0.932, p=0.000
# Se rechaza H0 → no es normal

# %% [markdown]
# Tenemos que las variables no siguen una distribución normal

# %%
df_original = df.copy()

# %% [markdown]
# ### **Imputación por Muestreo Aleatorio:**

# %% [markdown]
# #### **Creatinina:**

# %%
df_imputed = df.copy()

# %%
df_imputed = imputacion_muestreo_aleatorio(df_original,df_imputed,"Creatinina")
df_imputed.head()
# Out:
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo       0.900        82.26      73.0
# 1    75   1.63  28.228386         Negativo       0.700       116.28     102.0
# 2    97   1.68  34.367914         Negativo       1.700          NaN       NaN
# 3    65   1.62  24.767566         Negativo       1.100          NaN       NaN
# 4    70   1.57  28.398718         Negativo       0.792          NaN       NaN
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %%
analizar_misma_variable(df_original,df_imputed,"Creatinina")

# %%
distribucion_cruzada(df_original,df_imputed,"Creatinina")

# %%
pd.concat([df_original["Creatinina"].describe(), df_imputed["Creatinina"].describe()], axis=1, 
          keys=["Original", "Imputado"])
# Out:
#          Original     Imputado
# count  470.000000  1356.000000
# mean     1.156787     1.160124
# std      0.388140     0.390868
# min      0.600000     0.600000
# 25%      0.806750     0.812000
# 50%      1.000000     1.000000
# 75%      1.479500     1.484000
# max      2.500000     2.500000

# %%
prueba_kolmogrov(df_original,df_imputed,"Creatinina")
# Out:
# KS statistic: 0.011, p-value: 1.000
# No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran

# %% [markdown]
# #### **TFG_CDK_EPI**

# %%
df_imputed = imputacion_muestreo_aleatorio(df_imputed,df_imputed,"TFG_CDK_EPI")
df_imputed.head()
# Out:
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo       0.900        82.26      73.0
# 1    75   1.63  28.228386         Negativo       0.700       116.28     102.0
# 2    97   1.68  34.367914         Negativo       1.700       129.36       NaN
# 3    65   1.62  24.767566         Negativo       1.100        81.61       NaN
# 4    70   1.57  28.398718         Negativo       0.792        82.76       NaN
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %%
analizar_misma_variable(df_original,df_imputed,"TFG_CDK_EPI")

# %%
pd.concat([df_original["TFG_CDK_EPI"].describe(), df_imputed["TFG_CDK_EPI"].describe()], axis=1, 
          keys=["Original", "Imputado"])
# Out:
#          Original     Imputado
# count  470.000000  1356.000000
# mean    81.542596    81.148105
# std     31.470822    31.415531
# min     22.140000    22.140000
# 25%     54.545000    54.360000
# 50%     78.830000    78.790000
# 75%    105.972500   105.500000
# max    168.190000   168.190000

# %%
prueba_kolmogrov(df_original,df_imputed,"TFG_CDK_EPI")
# Out:
# KS statistic: 0.011, p-value: 1.000
# No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran

# %% [markdown]
# #### **TFG_Edad:**

# %%
df_imputed = imputacion_muestreo_aleatorio(df_imputed,df_imputed,"TFG_Edad")
df_imputed.head()
# Out:
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo       0.900        82.26      73.0
# 1    75   1.63  28.228386         Negativo       0.700       116.28     102.0
# 2    97   1.68  34.367914         Negativo       1.700       129.36      64.0
# 3    65   1.62  24.767566         Negativo       1.100        81.61      81.0
# 4    70   1.57  28.398718         Negativo       0.792        82.76      56.0
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %%
analizar_misma_variable(df_original,df_imputed,"TFG_Edad")

# %%
pd.concat([df_original["TFG_Edad"].describe(), df_imputed["TFG_Edad"].describe()], axis=1, 
          keys=["Original", "Imputado"])
# Out:
#          Original     Imputado
# count  470.000000  1356.000000
# mean    82.536170    82.315634
# std     17.417419    17.508984
# min     33.000000    33.000000
# 25%     71.250000    71.000000
# 50%     82.000000    82.000000
# 75%     94.000000    94.000000
# max    116.000000   116.000000

# %%
prueba_kolmogrov(df_original,df_imputed,"TFG_Edad")
# Out:
# KS statistic: 0.011, p-value: 1.000
# No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran

# %% [markdown]
# #### **Notas:**

# %% [markdown]
# Se llevó a cabo la imputación de las variables ``Creatinina``, ``TFG_CDK_EPI`` y ``TFG_Edad`` mediante un proceso de muestreo aleatorio. Posteriormente, se analizó la distribución de las variables imputadas y se realizó la prueba de Kolmogorov-Smirnov para comparar las distribuciones antes y después de la imputación. Los resultados obtenidos indican que no existen diferencias estadísticamente significativas entre las distribuciones originales y las imputadas, lo que sugiere que las imputaciones se realizaron con éxito y no alteraron de manera relevante las características distribucionales de las variables.

# %% [markdown]
# ### **Imputación por la Mediana:**

# %% [markdown]
# #### **Presion_Sistolica:**

# %%
df_imputed = imputacion_por_mediana(df_imputed,"Presion_Sistolica")
df_imputed.head()
# Out:
# C:\Users\Mari\AppData\Local\Temp\ipykernel_35676\153793866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna(mediana, inplace=True)
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo       0.900        82.26      73.0
# 1    75   1.63  28.228386         Negativo       0.700       116.28     102.0
# 2    97   1.68  34.367914         Negativo       1.700       129.36      64.0
# 3    65   1.62  24.767566         Negativo       1.100        81.61      81.0
# 4    70   1.57  28.398718         Negativo       0.792        82.76      56.0
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %%
analizar_misma_variable(df_original,df_imputed,"Presion_Sistolica")

# %%
distribucion_cruzada(df_original,df_imputed,"Presion_Sistolica")

# %%
pd.concat([df_original["Presion_Sistolica"].describe(), df_imputed["Presion_Sistolica"].describe()], axis=1, 
          keys=["Original", "Imputado"])
# Out:
#           Original     Imputado
# count  1309.000000  1356.000000
# mean    123.846448   123.713127
# std      16.641437    16.365417
# min      90.000000    90.000000
# 25%     111.000000   113.000000
# 50%     120.000000   120.000000
# 75%     130.000000   130.000000
# max     203.000000   203.000000

# %%
prueba_kolmogrov(df_original,df_imputed,"Presion_Sistolica")
# Out:
# KS statistic: 0.014, p-value: 0.999
# No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran

# %% [markdown]
# #### **Presion_Diastolica:**

# %%
df_imputed = imputacion_por_mediana(df_imputed,"Presion_Diastolica")
df_imputed.head()
# Out:
# C:\Users\Mari\AppData\Local\Temp\ipykernel_35676\153793866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna(mediana, inplace=True)
#               GRUPO Departamento_Tamizaje Municipio_Tamizaje  Edad    Genero  \
# 0  AFRODESCENDIENTE               BOLIVAR      MARIA LA BAJA    57  Femenino
# 1  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    28  Femenino
# 2  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    35  Femenino
# 3  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    19  Femenino
# 4  AFRODESCENDIENTE             ATLANTICO       BARRANQUILLA    44  Femenino
#
#   Escolaridad Regimen_Salud    Ocupacion Medicacion_Diabetes  \
# 0    Primaria    Subsidiado  Desempleado                  Si
# 1  Secundaria    Subsidiado  Desempleado                  No
# 2   Bachiller    Subsidiado  Desempleado                  No
# 3    Primaria      No tiene  Desempleado                  No
# 4   Bachiller    Subsidiado  Desempleado                  No
#
#   Diabetes_Embarazo Hipertension Medicacion_Hipertension Colesterol_Alto  \
# 0                No           Si                      Si              Si
# 1                Sí           No                      No              No
# 2                No           No                      No              No
# 3                No           No                      No              No
# 4                No           No                      No              No
#
#   Medicacion_Colesterol Insuficiencia_Renal Dialisis Proteina_Sangre_Orina  \
# 0                    Si                  No       No                    No
# 1                    No                  No       No                    No
# 2                    No                  No       No                    No
# 3                    No                  No       No                    No
# 4                    No                  No       No                    No
#
#   Alergias Nombre_Alergenos Consumo_Tabaco Fumador_100Cigs Consumo_Alcohol  \
# 0       No        No aplica             No              No              No
# 1       No        No aplica             No              No              Si
# 2       No        No aplica             No              No              Si
# 3       No        No aplica             No              No              Si
# 4       No        No aplica             No              No              No
#
#      Frecuencia_Alcohol Embriaguez Consumo_Drogas Trabajo_Cultivo  \
# 0                 Nunca         No             No              No
# 1     1-2 veces por mes         No             No              No
# 2  1-2 veces por semana         No             No              No
# 3     1-2 veces por mes         No             No              No
# 4                 Nunca         No             No              No
#
#   Uso_Insecticidas Uso_Fungicidas Uso_Fertilizantes Proteccion_Pesticidas  \
# 0               No             No                No             No aplica
# 1               No             No                No             No aplica
# 2               No             No                No             No aplica
# 3               No             No                No             No aplica
# 4               No             No                No             No aplica
#
#   Metodo_Aplicacion_Pesticidas Sintomas_Trabajo Consumo_Agua_Trabajo  \
# 0                    No aplica   No siente nada       Mas de 1 litro
# 1                    No aplica   No siente nada        Mas de 200 cc
# 2                    No aplica  Dolor de cabeza       Mas de 1 litro
# 3                    No aplica   No siente nada         No toma nada
# 4                    No aplica   No siente nada       Mas de 1 litro
#
#   Ultima_Consulta_Medica Dificultad_Atencion_Medica Ultimo_Profesional_Salud  \
# 0        Mayor a 3 meses                Muy Dificil               Internista
# 1        Mayor a 3 meses                    Difícil           Medico General
# 2         Mayor a 2 años                      Facil           Medico General
# 3         Mayor a 2 años                Muy Dificil           Medico General
# 4         Mayor a 2 años                    Difícil           Medico General
#
#   Medico_Cabecera Grupo_Sanguineo Transfusion_Sanguinea  \
# 0              Si              B+                    No
# 1              No              O+                    No
# 2              No              O+                    No
# 3              No              A+                    No
# 4              Si              O+                    No
#
#   Antecedentes_Familiares Familiar_Insuficiencia_Renal Familiar_Dialisis  \
# 0   Hipertensión Arterial                           No                No
# 1   Hipertensión Arterial                           No                No
# 2   Hipertensión Arterial                           Sí                No
# 3       Diabetes Mellitus                           No                No
# 4   Hipertensión Arterial                           No                No
#
#   Sintomas_Recientes Uso_AINES Uso_Medicina_Natural           Fuente_Agua  \
# 0            Ninguno        No                   No  Suministro municipal
# 1            Ninguno        No                   No  Suministro municipal
# 2    Dolor de cabeza        Si                   Si  Suministro municipal
# 3    Dolor de cabeza        Si                   Si  Suministro municipal
# 4            Ninguno        No                   No  Suministro municipal
#
#    Peso  Talla        IMC Tirilla_Reactiva  Creatinina  TFG_CDK_EPI  TFG_Edad  \
# 0    63   1.66  22.862534         Negativo       0.900        82.26      73.0
# 1    75   1.63  28.228386         Negativo       0.700       116.28     102.0
# 2    97   1.68  34.367914         Negativo       1.700       129.36      64.0
# 3    65   1.62  24.767566         Negativo       1.100        81.61      81.0
# 4    70   1.57  28.398718         Negativo       0.792        82.76      56.0
#
#    Presion_Sistolica  Presion_Diastolica Creatinina_Alta  \
# 0              175.0                89.0              No
# 1               97.0                70.0              No
# 2               92.0                68.0              No
# 3              105.0                63.0              No
# 4              126.0                71.0              No
#
#    Presion_Sistolica\t> 130  Presion_Diastolica > 90 Categoria_Talla  \
# 0                         1                        0       1.61-1.70
# 1                         0                        0       1.61-1.70
# 2                         0                        0       1.61-1.70
# 3                         0                        0       1.61-1.70
# 4                         0                        0       1.50-1.60
#
#   Categoria_Peso Categoria_IMC
# 0          61-80        Normal
# 1          61-80          Alto
# 2            >80    Obesidad 1
# 3          61-80        Normal
# 4          61-80          Alto

# %%
analizar_misma_variable(df_original,df_imputed,"Presion_Diastolica")

# %%
distribucion_cruzada(df_original,df_imputed,"Presion_Diastolica")

# %%
pd.concat([df_original["Presion_Diastolica"].describe(), df_imputed["Presion_Diastolica"].describe()], axis=1, 
          keys=["Original", "Imputado"])
# Out:
#           Original     Imputado
# count  1309.000000  1356.000000
# mean     79.395722    79.416667
# std      33.042103    32.464179
# min      28.000000    28.000000
# 25%      70.000000    70.000000
# 50%      80.000000    80.000000
# 75%      82.000000    82.000000
# max     880.000000   880.000000

# %%
prueba_kolmogrov(df_original,df_imputed,"Presion_Diastolica")
# Out:
# KS statistic: 0.016, p-value: 0.994
# No hay evidencia estadísticamente significativa que evidencia que las distribuciones difieran

# %% [markdown]
# #### **Nota:**

# %% [markdown]
# Se llevó a cabo la imputación de las variables ``Presion_Sistolica`` y ``Presion_Diastolica`` mediante un proceso de muestreo aleatorio. Posteriormente, se analizó la distribución de las variables imputadas y se realizó la prueba de Kolmogorov-Smirnov para comparar las distribuciones antes y después de la imputación. Los resultados obtenidos indican que no existen diferencias estadísticamente significativas entre las distribuciones originales y las imputadas, lo que sugiere que las imputaciones se realizaron con éxito y no alteraron de manera relevante las características distribucionales de las variables.

# %% [markdown]
# ### **Revision de Valores Faltantes:**

# %%
Resumen_Faltantes(df_imputed)
# Out:
# Empty DataFrame
# Columns: [Valores faltantes, Porcentaje (%)]
# Index: []

# %%
plt.figure(figsize = (20,6))
sns.heatmap(df_imputed.isnull(),cbar=False,cmap= "Blues")
plt.title("Mapa de calor de Valores Faltantes")
plt.xlabel("Variables")
plt.ylabel("Regsitros")
plt.show()
# Out:
# c:\Users\Mari\miniconda3\envs\deepl_venv\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Mari\miniconda3\envs\deepl_venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
